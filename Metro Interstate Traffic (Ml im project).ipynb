# %%
# import all required libraries for reading, analysing and visualizing data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import sqrt

# %%
#importing data
train_df = pd.read_csv("D:\\Metro_Interstate_Traffic_Volume.csv")

# %% [markdown]
# ## Data Description and stats

# %%
print('Dataset shape: ', train_df.shape)
# Out:
# Dataset shape:  (48204, 9)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %%
train_df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %%
train_df.describe(include = 'all')
# Out:
#        holiday          temp       rain_1h       snow_1h    clouds_all  \
# count    48204  48204.000000  48204.000000  48204.000000  48204.000000
# unique      12           NaN           NaN           NaN           NaN
# top       None           NaN           NaN           NaN           NaN
# freq     48143           NaN           NaN           NaN           NaN
# mean       NaN    281.205870      0.334264      0.000222     49.362231
# std        NaN     13.338232     44.789133      0.008168     39.015750
# min        NaN      0.000000      0.000000      0.000000      0.000000
# 25%        NaN    272.160000      0.000000      0.000000      1.000000
# 50%        NaN    282.450000      0.000000      0.000000     64.000000
# 75%        NaN    291.806000      0.000000      0.000000     90.000000
# max        NaN    310.070000   9831.300000      0.510000    100.000000
#
#        weather_main weather_description            date_time  traffic_volume
# count         48204               48204                48204    48204.000000
# unique           11                  38                40575             NaN
# top          Clouds        sky is clear  2013-05-19 10:00:00             NaN
# freq          15164               11665                    6             NaN
# mean            NaN                 NaN                  NaN     3259.818355
# std             NaN                 NaN                  NaN     1986.860670
# min             NaN                 NaN                  NaN        0.000000
# 25%             NaN                 NaN                  NaN     1193.000000
# 50%             NaN                 NaN                  NaN     3380.000000
# 75%             NaN                 NaN                  NaN     4933.000000
# max             NaN                 NaN                  NaN     7280.000000

# %%
train_df.isnull().sum()
# Out:
# holiday                0
# temp                   0
# rain_1h                0
# snow_1h                0
# clouds_all             0
# weather_main           0
# weather_description    0
# date_time              0
# traffic_volume         0
# dtype: int64

# %% [markdown]
# ## DATA CLEANING

# %%
# convert the date_time column to datetime type
train_df['date_time'] = pd.to_datetime(train_df['date_time'])

# %%
train_df['time'] = train_df['date_time'].dt.hour

# %%
train_df['month'] = train_df['date_time'].dt.month

# %%
train_df['year'] = train_df['date_time'].dt.year

# %%
train_df['day'] = train_df['date_time'].dt.day_name()

# %%
train_df['holiday'].value_counts()
# Out:
# None                         48143
# Labor Day                        7
# Thanksgiving Day                 6
# Christmas Day                    6
# New Years Day                    6
# Martin Luther King Jr Day        6
# Columbus Day                     5
# Veterans Day                     5
# Washingtons Birthday             5
# Memorial Day                     5
# Independence Day                 5
# State Fair                       5
# Name: holiday, dtype: int64

# %%
z = lambda x: False if x == 'None' else True
train_df['holiday'] = train_df['holiday'].apply(z)

# %%
cols =['clouds_all','rain_1h','snow_1h','temp','traffic_volume']
sns.pairplot(train_df[cols])
plt.show()

# %%
plt.figure(figsize=(14,15))
plt.subplot(3,2,1)
plt.boxplot(train_df['clouds_all'])
plt.ylim(0,130)
plt.title('clouds_all')

plt.subplot(3,2,2)
plt.boxplot(train_df['rain_1h'])
plt.title('rain_1h')

plt.subplot(3,2,3)
plt.boxplot(train_df['snow_1h'])
plt.title('snow_1h')

plt.subplot(3,2,4)
plt.boxplot(train_df['temp'])
plt.title('temp')

plt.subplot(3,2,5)
plt.boxplot(train_df['traffic_volume'])
plt.title('traffic_volume')

plt.show()

# %%
train_df = train_df[train_df['temp'] != 0]

# %%
train_df = train_df[train_df.rain_1h < 100]

# %% [markdown]
# ## DATA VISUALIZATION

# %%
fig, (axis2) = plt.subplots( 1, figsize = (12,4))
sns.lineplot(x = 'time', y = 'traffic_volume', data = train_df, ax = axis2);
plt.show()

# %% [markdown]
# This indicates that metro is busiest in between afternoon and evening

# %%
fig, (axis2) = plt.subplots( 1, figsize = (12,4))
sns.lineplot(x = 'month', y = 'traffic_volume', data = train_df, ax = axis2);
plt.show()

# %% [markdown]
# June ,August,October are the busiest months

# %%
fig, (axis1) = plt.subplots(1,  figsize = (12,4))
sns.countplot(x = 'year', data = train_df, ax = axis1)
plt.show()

# %% [markdown]
# 2017 turned out to be full capacitied month for us metro

# %%
fig, (axis1,axis2) = plt.subplots(1, 2, figsize = (20,6))
sns.countplot(x = 'day', data = train_df, ax = axis1)
sns.lineplot(x = 'day', y = 'traffic_volume', data = train_df, ax = axis2);
plt.show()

# %% [markdown]
# Metro were least used on Wednesday

# %%
fig, (axis1,axis2) = plt.subplots(1, 2, figsize = (20,6))
sns.countplot(x = 'holiday', data = train_df, ax = axis1)
sns.barplot(x = 'holiday', y = 'traffic_volume', data = train_df, ax = axis2);
plt.show()

# %% [markdown]
# Metros were used more on working days rather than on holidays

# %%
#exploring different categories in weather_main
df=pd.read_csv("D:\Metro_Interstate_Traffic_Volume.csv")
sns.countplot(y='weather_main', data=df) 
plt.show()

# %% [markdown]
# It indicates that climate in us is mostly cloudy and clear

# %%
plt.figure(figsize=(8, 5))
plt.title('Correlation between features')
sns.heatmap(train_df.corr(), annot = True);
plt.show()

# %% [markdown]
# Nearly no Correlation between fields

# %%
train_df.columns
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume', 'time', 'month',
#        'year', 'day'],
#       dtype='object')

# %% [markdown]
# ## PRE PROCESSING

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# drop the unrequired columns
train_df.drop(['date_time', 'weather_description'], axis = 1, inplace = True)

# %%
# convert values of day column to numerical format
encoder = LabelEncoder()
train_df['day'] = encoder.fit_transform(train_df['day'])

# %%
# subtract 242 from the temp column as there is no temperature below it
train_df['temp'] = train_df['temp'] - 242

# %%
# convert the values of weather_main column to numerical format
encoder = LabelEncoder()
train_df['weather_main'] = encoder.fit_transform(train_df['weather_main'])

# %% [markdown]
# ## ML MODELS

# %%
# import the required modules
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
(X, Y) = (train_df.drop(['traffic_volume'], axis = 1).values, train_df['traffic_volume'].values)

# Scale the values
scaler = StandardScaler()
X = scaler.fit_transform(X)

(X_train, X_val, Y_train, Y_val) = train_test_split(X, Y)
print("X_train shape:" + str(X_train.shape))
print("Y_train shape:" + str(Y_train.shape))
print("X_val shape:" + str(X_val.shape))
print("Y_val shape:" + str(Y_val.shape))
# Out:
# X_train shape:(36144, 10)
# Y_train shape:(36144,)
# X_val shape:(12049, 10)
# Y_val shape:(12049,)

# %%
# DataFrame to store the RMSE scores of various algorithms
results = pd.DataFrame(columns = ['RMSE'])

# %%
import math

# %%
# helper function to evaluate a model
def evaluate_model(regressor, name):
    # train and test scores
    train_score = round(regressor.score(X_train, Y_train), 2)
    val_score = round(regressor.score(X_val, Y_val), 2)
    # predicted output
    Y_pred = regressor.predict(X_val)

    print(name + ' Train score: ', train_score)
    print(name + 'Test score: ', val_score)
    print('Root Mean Squared error: ', sqrt(mean_squared_error(Y_val, Y_pred)))
    print('Coefficient of determination: ', r2_score(Y_val, Y_pred))
    
    # add the current RMSE to the scores list
    results.loc[name] = sqrt(mean_squared_error(Y_val, Y_pred))
    
    # plot predicted vs true values
    x_points=np.linspace(0,8e3)
    plt.figure(figsize=(12,5))
    plt.plot(x_points, x_points, color='r')
    plt.scatter(Y_val, Y_pred)
    plt.xlabel('True Values')
    plt.ylabel('Predicted Values')
    plt.title('True Values Vs Predicted Values');
    plt.show()

# %%
lireg = LinearRegression()
lireg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# evaluate the Regressor
evaluate_model(lireg, 'Linear Regression')
# Out:
# Linear Regression Train score:  0.15
# Linear RegressionTest score:  0.13
# Root Mean Squared error:  1857.2600551696764
# Coefficient of determination:  0.12807637834182373

# %%
dtreg = DecisionTreeRegressor(max_depth = 12)
dtreg.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=12)

# %%
# EVALUATING DECISION TREE
evaluate_model(dtreg,'Decision Tree')
# Out:
# Decision Tree Train score:  0.96
# Decision TreeTest score:  0.94
# Root Mean Squared error:  503.58081610327037
# Coefficient of determination:  0.935898032221618

# %%
# n_estimators - The number of trees in the forest.
# min_samples_split - The minimum number of samples required to split an internal node
rfreg = RandomForestRegressor(n_estimators = 50, max_depth = 12, min_samples_split = 5)
rfreg.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(max_depth=12, min_samples_split=5, n_estimators=50)

# %%
# evaluate the Regressor
evaluate_model(rfreg, 'Random Forest')
# Out:
# Random Forest Train score:  0.97
# Random ForestTest score:  0.95
# Root Mean Squared error:  461.16858968041623
# Coefficient of determination:  0.9462408434426076

# %%
### Using Gradient Boosting

# n_estimators - The number of boosting stages to perform.
# max_depth - maximum depth of the individual regression estimators.
gbreg = GradientBoostingRegressor(n_estimators=500, max_depth=10)
gbreg.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(max_depth=10, n_estimators=500)

# %%
# evaluate the Regressor
evaluate_model(gbreg, 'Gradient Boosting')
# Out:
# Gradient Boosting Train score:  1.0
# Gradient BoostingTest score:  0.96
# Root Mean Squared error:  381.43000710792546
# Coefficient of determination:  0.9632241500368107

# %%
### Using AdaBoost

# n_estimators - The number of trees in the forest.
# learning_rate - Learning rate shrinks the contribution of each classifier by learning_rate.
adareg = AdaBoostRegressor(base_estimator=dtreg, n_estimators=50, learning_rate=0.01)
adareg.fit(X_train, Y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=12),
#                   learning_rate=0.01)

# %%
# evaluate the Regressor
evaluate_model(adareg, 'Ada Boost')
# Out:
# Ada Boost Train score:  0.97
# Ada BoostTest score:  0.95
# Root Mean Squared error:  462.16493505397494
# Coefficient of determination:  0.9460083013802426

# %%
plt.plot(gbreg.feature_importances_)
plt.show()

# %%
#XGBOOST REGRESSOR
import xgboost as xgb
xgb_model = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 100)
xgb_model.fit(X_train, Y_train)
# Out:
# XGBRegressor(alpha=10, base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.3,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=5, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=10, ...)

# %%
# EVALUATING MODEL
evaluate_model(xgb_model, 'XG Boost')
# Out:
# XG Boost Train score:  0.86
# XG BoostTest score:  0.85
# Root Mean Squared error:  772.0393033985091
# Coefficient of determination:  0.8493351903267294

# %%
## KNN MOdel
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=5)
knn_model.fit(X_train, Y_train)
# Out:
# KNeighborsRegressor()

# %%
#EVALUATING THE MODEL
evaluate_model(knn_model,'KNN')
# Out:
# KNN Train score:  0.88
# KNNTest score:  0.81
# Root Mean Squared error:  861.8995902347185
# Coefficient of determination:  0.812221288201798

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

en = ElasticNet(alpha=1.0, l1_ratio=0.5, random_state=42)

# Fit the model on the training data
en.fit(X_train, Y_train)
# Out:
# ElasticNet(random_state=42)

# %%
evaluate_model(en,'Elastic Net Regression')
# Out:
# Elastic Net Regression Train score:  0.13
# Elastic Net RegressionTest score:  0.12
# Root Mean Squared error:  1867.5698482944183
# Coefficient of determination:  0.11836928059135021

# %%
from sklearn.svm import SVR
svr = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr.fit(X_train, Y_train)
# Out:
# SVR(C=100, gamma=0.1)

# %%
#EVALUATE
evaluate_model(svr,'SVR')
# Out:
# SVR Train score:  0.69
# SVRTest score:  0.68
# Root Mean Squared error:  1125.2718822555075
# Coefficient of determination:  0.6799278102597801

# %%
## Comparison between all the above algorithms
results
# Out:
#                                RMSE
# Linear Regression       1857.260055
# Decision Tree            503.580816
# Random Forest            461.168590
# Gradient Boosting        381.430007
# Ada Boost                462.164935
# XG Boost                 772.039303
# KNN                      861.899590
# Elastic Net Regression  1867.569848
# SVR                     1125.271882

# %%
train_df.to_csv('Cleaned_data.csv')

# %%
from sklearn.model_selection import GridSearchCV, train_test_split

# %%
# Define the parameter grid for grid search
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.05, 0.1, 0.15],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 4, 6]
}

# Define the gradient boosting regressor model
gb_model = GradientBoostingRegressor(random_state=42)

# Perform grid search
grid_search = GridSearchCV(gb_model, param_grid, scoring='neg_mean_squared_error', cv=5, verbose=3)
grid_search.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=100;, score=-492809.313 total time=   2.4s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=100;, score=-512227.853 total time=   2.5s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=100;, score=-499392.904 total time=   2.5s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=100;, score=-491194.642 total time=   2.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=100;, score=-505312.447 total time=   2.4s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=200;, score=-399810.541 total time=   4.6s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=200;, score=-403643.565 total time=   4.3s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=200;, score=-416785.826 total time=   4.4s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=200;, score=-400035.074 total time=   4.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=200;, score=-396350.602 total time=   4.6s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=300;, score=-319309.369 total time=   6.8s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=300;, score=-332935.619 total time=   6.8s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=300;, score=-349752.942 total time=   6.8s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=300;, score=-341061.022 total time=   7.6s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=2, n_estimators=300;, score=-347351.016 total time=   7.0s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=100;, score=-492809.313 total time=   2.3s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=100;, score=-512227.853 total time=   2.3s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=100;, score=-499392.904 total time=   2.3s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=100;, score=-491194.642 total time=   2.2s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=100;, score=-505312.447 total time=   2.3s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=200;, score=-399810.541 total time=   4.7s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=200;, score=-403643.565 total time=   4.8s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=200;, score=-416785.828 total time=   4.6s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=200;, score=-400035.069 total time=   4.7s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=200;, score=-396350.602 total time=   4.7s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=300;, score=-319341.520 total time=   7.1s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=300;, score=-332935.615 total time=   7.2s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=300;, score=-349754.423 total time=   7.0s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=300;, score=-341063.303 total time=   7.4s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=4, n_estimators=300;, score=-358918.388 total time=   7.0s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=100;, score=-492809.313 total time=   2.3s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=100;, score=-512227.853 total time=   2.3s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=100;, score=-499392.904 total time=   2.3s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=100;, score=-491194.642 total time=   2.3s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=100;, score=-505312.447 total time=   2.4s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=200;, score=-399810.541 total time=   4.7s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=200;, score=-403645.617 total time=   5.0s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=200;, score=-416785.828 total time=   4.7s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=200;, score=-400035.069 total time=   4.8s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=200;, score=-401117.109 total time=   4.7s
# [CV 1/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=300;, score=-319329.955 total time=   7.2s
# [CV 2/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=300;, score=-332932.654 total time=   7.1s
# [CV 3/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=300;, score=-349754.423 total time=   7.3s
# [CV 4/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=300;, score=-341065.048 total time=   7.0s
# [CV 5/5] END learning_rate=0.05, max_depth=3, min_samples_split=6, n_estimators=300;, score=-345409.596 total time=   7.3s
# [CV 1/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=100;, score=-316054.533 total time=   3.1s
# [CV 2/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=100;, score=-341424.580 total time=   3.1s
# [CV 3/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=100;, score=-345635.170 total time=   3.0s
# [CV 4/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=100;, score=-329286.258 total time=   3.1s
# [CV 5/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=100;, score=-336742.959 total time=   3.0s
# [CV 1/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=200;, score=-245542.170 total time=   6.3s
# [CV 2/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=200;, score=-274381.850 total time=   6.1s
# [CV 3/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=200;, score=-282832.373 total time=   6.3s
# [CV 4/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=200;, score=-277400.849 total time=   6.3s
# [CV 5/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=200;, score=-273644.769 total time=   6.2s
# [CV 1/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=300;, score=-228995.379 total time=   9.5s
# [CV 2/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=300;, score=-250478.077 total time=   8.8s
# [CV 3/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=300;, score=-257084.531 total time=   9.0s
# [CV 4/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=300;, score=-260320.936 total time=   8.9s
# [CV 5/5] END learning_rate=0.05, max_depth=4, min_samples_split=2, n_estimators=300;, score=-250275.843 total time=   8.8s
# [CV 1/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=100;, score=-316054.533 total time=   2.9s
# [CV 2/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=100;, score=-341424.580 total time=   2.8s
# [CV 3/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=100;, score=-345635.170 total time=   2.8s
# [CV 4/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=100;, score=-329286.258 total time=   2.8s
# [CV 5/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=100;, score=-336742.959 total time=   2.8s
# [CV 1/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=200;, score=-246102.002 total time=   5.9s
# [CV 2/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=200;, score=-274053.632 total time=   5.9s
# [CV 3/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=200;, score=-282789.430 total time=   5.8s
# [CV 4/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=200;, score=-278470.471 total time=   5.7s
# [CV 5/5] END learning_rate=0.05, max_depth=4, min_samples_split=4, n_estimators=200;, score=
9s
# [CV 3/5] END learning_rate=0.15, max_depth=4, min_samples_split=2, n_estimators=300;, score=-207550.966 total time=   9.1s
# [CV 4/5] END learning_rate=0.15, max_depth=4, min_samples_split=2, n_estimators=300;, score=-208998.694 total time=   8.9s
# [CV 5/5] END learning_rate=0.15, max_depth=4, min_samples_split=2, n_estimators=300;, score=-200484.395 total time=   9.0s
# [CV 1/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=100;, score=-230491.840 total time=   2.9s
# [CV 2/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=100;, score=-242156.293 total time=   2.9s
# [CV 3/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=100;, score=-250553.780 total time=   2.9s
# [CV 4/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=100;, score=-251619.886 total time=   2.9s
# [CV 5/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=100;, score=-245394.491 total time=   2.9s
# [CV 1/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=200;, score=-203523.899 total time=   5.9s
# [CV 2/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=200;, score=-213905.535 total time=   5.9s
# [CV 3/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=200;, score=-214216.373 total time=   5.9s
# [CV 4/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=200;, score=-220913.455 total time=   6.0s
# [CV 5/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=200;, score=-214098.087 total time=   5.8s
# [CV 1/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=300;, score=-187828.914 total time=   8.9s
# [CV 2/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=300;, score=-205006.954 total time=   8.8s
# [CV 3/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=300;, score=-205299.768 total time=   8.9s
# [CV 4/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=300;, score=-206552.549 total time=   8.8s
# [CV 5/5] END learning_rate=0.15, max_depth=4, min_samples_split=4, n_estimators=300;, score=-205959.455 total time=   8.9s
# [CV 1/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=100;, score=-230708.811 total time=   2.9s
# [CV 2/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=100;, score=-242750.505 total time=   2.9s
# [CV 3/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=100;, score=-247757.116 total time=   2.9s
# [CV 4/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=100;, score=-243818.722 total time=   3.1s
# [CV 5/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=100;, score=-250183.535 total time=   2.9s
# [CV 1/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=200;, score=-206839.637 total time=   5.8s
# [CV 2/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=200;, score=-220378.348 total time=   5.8s
# [CV 3/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=200;, score=-215507.447 total time=   5.9s
# [CV 4/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=200;, score=-223533.457 total time=   5.9s
# [CV 5/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=200;, score=-226600.378 total time=   5.9s
# [CV 1/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=300;, score=-188807.647 total time=   8.8s
# [CV 2/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=300;, score=-211268.142 total time=   8.8s
# [CV 3/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=300;, score=-204918.088 total time=   8.8s
# [CV 4/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=300;, score=-208162.020 total time=   8.7s
# [CV 5/5] END learning_rate=0.15, max_depth=4, min_samples_split=6, n_estimators=300;, score=-206744.958 total time=   8.8s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=100;, score=-183723.435 total time=   3.6s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=100;, score=-201114.982 total time=   3.6s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=100;, score=-203009.550 total time=   3.6s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=100;, score=-206585.616 total time=   3.6s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=100;, score=-193681.724 total time=   3.6s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=200;, score=-173655.822 total time=   7.3s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=200;, score=-189560.389 total time=   7.2s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=200;, score=-188694.973 total time=   7.3s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=200;, score=-192324.072 total time=   7.6s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=200;, score=-184077.933 total time=   7.2s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=300;, score=-169446.390 total time=  10.8s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=300;, score=-187748.825 total time=  10.9s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=300;, score=-181675.760 total time=  11.0s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=300;, score=-184662.836 total time=  10.8s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=2, n_estimators=300;, score=-181258.408 total time=  10.9s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=100;, score=-183927.385 total time=   3.6s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=100;, score=-201933.866 total time=   3.6s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=100;, score=-204031.021 total time=   3.6s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=100;, score=-206206.253 total time=   3.6s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=100;, score=-198659.976 total time=   3.6s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=200;, score=-172718.436 total time=   7.2s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=200;, score=-191346.691 total time=   7.3s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=200;, score=-189728.361 total time=   7.3s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=200;, score=-189591.105 total time=   7.2s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=200;, score=-181562.591 total time=   7.5s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=300;, score=-167171.384 total time=  10.9s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=300;, score=-186227.032 total time=  10.9s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=300;, score=-185108.991 total time=  10.9s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=300;, score=-184454.739 total time=  10.9s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=4, n_estimators=300;, score=-176862.794 total time=  11.0s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=100;, score=-181641.308 total time=   3.7s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=100;, score=-204410.915 total time=   3.6s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=100;, score=-204209.699 total time=   3.7s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=100;, score=-205506.249 total time=   3.7s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=100;, score=-198750.297 total time=   3.6s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=200;, score=-171442.637 total time=   7.1s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=200;, score=-193401.700 total time=   7.1s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=200;, score=-189784.622 total time=   6.9s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=200;, score=-190829.434 total time=   7.1s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=200;, score=-184893.910 total time=   7.0s
# [CV 1/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=300;, score=-166969.810 total time=  11.2s
# [CV 2/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=300;, score=-188876.623 total time=  10.8s
# [CV 3/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=300;, score=-183414.515 total time=  10.7s
# [CV 4/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=300;, score=-182202.285 total time=  11.2s
# [CV 5/5] END learning_rate=0.15, max_depth=5, min_samples_split=6, n_estimators=300;, score=-179436.791 total time=  10.8s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(random_state=42),
#              param_grid={'learning_rate': [0.05, 0.1, 0.15],
#                          'max_depth': [3, 4, 5], 'min_samples_split': [2, 4, 6],
#                          'n_estimators': [100, 200, 300]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
# Predict on the test set
predictions = grid_search.predict(X_val)

# Compute evaluation metrics
mse = mean_squared_error(Y_val, predictions)
rmse = np.sqrt(mse)

# Print the best parameters and evaluation metrics for the grid search
print("Grid Search Results:")
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Negative Mean Squared Error: {-grid_search.best_score_:.2f}")
print(f"RMSE on Test Set: {rmse:.2f}")
# Out:
# Grid Search Results:
# Best Parameters: {'learning_rate': 0.15, 'max_depth': 5, 'min_samples_split': 4, 'n_estimators': 300}
# Best Negative Mean Squared Error: 179964.99
# RMSE on Test Set: 429.15

# %%
results
# Out:
#                                RMSE
# Linear Regression       1857.260055
# Decision Tree            503.580816
# Random Forest            461.168590
# Gradient Boosting        381.430007
# Ada Boost                462.164935
# XG Boost                 772.039303
# KNN                      861.899590
# Elastic Net Regression  1867.569848
# SVR                     1125.271882
